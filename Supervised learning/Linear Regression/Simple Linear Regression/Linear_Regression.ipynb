# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here we have a graph where the horizontal axis is the size of the house in square feet,\
# and the vertical axis is the priveof the house in thousands of dollars\
# Here at each data point, each of these little crosses is a house with a size and a price that is mostly recently was sold for.
#
#
# one thing you could do is you can build a **linear regression** for this data set,\
# Your model will fit a straight line to the data like this

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Terminology
# ### Training set (训练集): Data used to train the model
# The data set that you just saw and that is used to train the model is called a **training set**
# - Note thar your client's house is not in this data set because it's not yet sold, so no one knows
#
# ### x = "input" variable feature(输入/输入特征)
# ### y = "output" variable / "target" variable (目标变量)
# ### m = number of training example (训练样本总数)
# ### (x,y) = single training example (训练样本)
# ![image.png](attachment:image.png)

# %% [markdown]
# like this\
# x = size in $feet^2$(2104)\
# y = price in $1000's(400)\
# m = 47\
# (x,y) = (2104,400)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The function f is called the model
# y-hat is the estimate or the prediction, for y
# x is called the input or input feature
#
# # How to represent *f*?
# $f_{w,b}(x) = wx + b$\
# *w,b* are called the parameters of the model\
# So this f w b of x means f is a function that takes x depending y

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It's making predictions for the value of y using a straight line to predict y
#
# Sometimes you want to fit more complex nonlinear functions as well
# But linear is easy, and is foundation of nonlinear
#
# This line is called Linear regression
# this is linear regression with one variable(单变量线性回归)
